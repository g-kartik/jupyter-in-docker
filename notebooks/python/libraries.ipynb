# %% [markdown]
# # Fraction

# %%
from fractions import Fraction

# %%
f = Fraction(15, 1)

# %%
f.numerator
# Out:
# 15

# %% [markdown]
# # Getters and Setters

# %%
class Person:
    
    def __init__(self, name=None, age=None, gender=None):
        self._name = name
        self._age = age
        self._gender = gender
        
    def get_name(self):
        return self._name
    
    def get_age(self):
        return self._age
    
    def get_gender(self):
        return self.gender
    
    def set_name(self, name):
        self._name = name
        
    def set_age(self, age):
        self._age = age
        
    def set_gender(self, gender):
        self._gender = gender
        
    def del_name(self):
        del self._name
        
    def del_age(self):
        del self._age
        
    def del_gender(self):
        del self._gender
        
    name = property(get_name, set_name, del_name)
    age = property(get_age, set_age, del_age)
    gender = property(get_gender, set_gender, del_gender)
    
    def __repr__(self):
        return 
    
    def __iter__(self):
        return

# %%
p1 = Person()

# %%
p1.name = "Karthik"

# %%
p1.age = 27

# %%
p1.gender = "Male"

# %%
p1.name
# Out:
# 'Karthik'

# %%
del p1.name

# %% [markdown]
# # IO Library

# %%
import io

# %%
file = io.BytesIO(initial_bytes=b'foo')

# %%
file.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 file.read()
#
# ValueError: I/O operation on closed file.

# %%
file.seek(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 file.seek(0)
#
# ValueError: I/O operation on closed file.

# %%
file.close()

# %%
with file as f:
    print(f.read())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 with file as f:
#       2     print(f.read())
#
# ValueError: I/O operation on closed file.

# %% [markdown]
# # MIME type
#
#     A MIME type (now properly called "media type", but also sometimes "content type") is a string sent along with a file indicating the type of the file (describing the content format, for example, a sound file might be labeled audio/ogg, or an image file image/png).

# %% [markdown]
# ## Useful references
# - POST: https://developer.mozilla.org/en-US/docs/Web/HTTP/Methods/POST
# - Form Data: https://developer.mozilla.org/en-US/docs/Web/API/FormData
# - Content Encoding: https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Content-Encoding
# - Common MIME types: https://developer.mozilla.org/en-US/docs/Web/HTTP/Basics_of_HTTP/MIME_types/Common_types
# - MIME types (IANA media types): https://developer.mozilla.org/en-US/docs/Web/HTTP/Basics_of_HTTP/MIME_types
# - Transfer-Encoding: https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Transfer-Encoding

# %%
import mimetypes
from pathlib import Path

# %%
mimetypes.guess_type("video_1.mp4")
# Out:
# ('video/mp4', None)

# %%
file = Path('1. Enter - Naruto Uzumaki!.mp4')

# %%
file
# Out:
# PosixPath('1. Enter - Naruto Uzumaki!.mp4')

# %%
mimetypes.guess_type(file)
# Out:
# ('video/mp4', None)

# %% [markdown]
# ## mimetypes.guess_extension(type, strict=True)
#
#     Guess the extension for a file based on its MIME type, given by type. The return value is a string giving a filename extension, including the leading dot ('.'). The extension is not guaranteed to have been associated with any particular data stream, but would be mapped to the MIME type type by guess_type(). If no extension can be guessed for type, None is returned.
#
#     The optional strict argument has the same meaning as with the guess_type() function.

# %%
mimetypes.guess_extension('gzip')

# %% [markdown]
# ## mimetypes.knownfiles
# List of type map file names commonly installed. These files are typically named mime.types and are installed in different locations by different packages.

# %%
mimetypes.knownfiles
# Out:
# ['/etc/mime.types',
#  '/etc/httpd/mime.types',
#  '/etc/httpd/conf/mime.types',
#  '/etc/apache/mime.types',
#  '/etc/apache2/mime.types',
#  '/usr/local/etc/httpd/conf/mime.types',
#  '/usr/local/lib/netscape/mime.types',
#  '/usr/local/etc/httpd/conf/mime.types',
#  '/usr/local/etc/mime.types']

# %% [markdown]
# # AV Library

# %%
import av
import PIL
from pathlib import Path
from pprint import pprint

# %%
path = str(Path("assets/parmeshwar.mp4").absolute())

# %% [markdown]
# ### Input Container and its methods

# %% [markdown]
# Open the video in an input container

# %%
print(av.open.__doc__)
# Out:
# open(file, mode='r', **kwargs)
#
#     Main entrypoint to opening files/streams.
#
#     :param str file: The file to open, which can be either a string or a file-like object.
#     :param str mode: ``"r"`` for reading and ``"w"`` for writing.
#     :param str format: Specific format to use. Defaults to autodect.
#     :param dict options: Options to pass to the container and all streams.
#     :param dict container_options: Options to pass to the container.
#     :param list stream_options: Options to pass to each stream.
#     :param str metadata_encoding: Encoding to use when reading or writing file metadata.
#         Defaults to ``"utf-8"``.
#     :param str metadata_errors: Specifies how to handle encoding errors; behaves like
#         ``str.encode`` parameter. Defaults to ``"strict"``.
#     :param int buffer_size: Size of buffer for Python input/output operations in bytes.
#         Honored only when ``file`` is a file-like object. Defaults to 32768 (32k).
# ...

# %%
input_container = av.open(path, mode='r')
print("Type:", type(input_container), end='\n\n')
print("Dir:", dir(input_container))
# Out:
# Type: <class 'av.container.input.InputContainer'>
#
# Dir: ['__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__pyx_vtable__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '_get_flags', '_set_flags', 'auto_bsf', 'bit_exact', 'bit_rate', 'close', 'container_options', 'custom_io', 'decode', 'demux', 'discard_corrupt', 'dumps_format', 'duration', 'fast_seek', 'file', 'flags', 'flush_packets', 'format', 'gen_pts', 'ign_dts', 'ign_idx', 'io_open', 'metadata', 'metadata_encoding', 'metadata_errors', 'name', 'no_buffer', 'no_fill_in', 'no_parse', 'non_block', 'open_files', 'open_timeout', 'options', 'priv_opt', 'read_timeout', 'seek', 'shortest', 'size', 'sort_dts', 'start_time', 'stream_options', 'streams', 'writeable']

# %% [markdown]
# ### Streams
# A container can contain streams, which on decoding yield frames
# https://pyav.org/docs/develop/api/stream.html

# %%
type(input_container.streams)
# Out:
# av.container.streams.StreamContainer

# %%
dir(input_container.streams)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'audio',
#  'data',
#  'get',
#  'other',
#  'subtitles',
#  'video']

# %%
pprint(input_container.streams.get.__doc__)
# Out:
# ('get(streams=None, video=None, audio=None, subtitles=None, data=None)\n'
#  '\n'
#  '        Get a selection of :class:`.Stream` as a ``list``.\n'
#  '\n'
#  '        Positional arguments may be ``int`` (which is an index into the '
#  'streams),\n'
#  '        or ``list`` or ``tuple`` of those::\n'
#  '\n'
#  '            # Get the first channel.\n'
#  '            streams.get(0)\n'
#  '\n'
#  '            # Get the first two audio channels.\n'
#  '            streams.get(audio=(0, 1))\n'
#  '\n'
#  '        Keyword arguments (or dicts as positional arguments) as interpreted\n'
#  '        as ``(stream_type, index_value_or_set)`` pairs::\n'
#  '\n'
#  '            # Get the first video channel.\n'
#  '            streams.get(video=0)\n'
#  '            # or\n'
#  "            streams.get({'video': 0})\n"
#  '\n'
#  '        :class:`.Stream` objects are passed through untouched.\n'
#  '\n'
#  '        If nothing is selected, then all streams are returned.\n'
#  '\n'
#  '        ')

# %%
input_container.streams.audio
# Out:
# ()

# %%
input_container.streams.video
# Out:
# (<av.VideoStream #0 h264, yuv444p 1920x1080 at 0x7f4fd7c2b4c0>,)

# %%
video_stream = input_container.streams.video[0]

# %%
pprint(type(video_stream))
# Out:
# <class 'av.video.stream.VideoStream'>

# %%
print('frame_rate: ', int(video_stream.average_rate))
# Out:
# frame_rate:  15

# %%
round(float(video_stream.duration * video_stream.time_base/60), 2)
# Out:
# 0.81

# %%
frame_generator = input_container.decode(video_stream)

# %%
print(type(frame_generator))
# Out:
# <class 'generator'>

# %%
frame = next(frame_generator)

# %%
print(type(frame))
# Out:
# <class 'av.video.frame.VideoFrame'>

# %%
print(dir(frame))
# Out:
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__pyx_vtable__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', 'dts', 'format', 'from_image', 'from_ndarray', 'height', 'index', 'interlaced_frame', 'is_corrupt', 'key_frame', 'pict_type', 'planes', 'pts', 'reformat', 'side_data', 'time', 'time_base', 'to_image', 'to_ndarray', 'to_rgb', 'width']

# %%
image = frame.to_image()

# %%
print(type(image))
# Out:
# <class 'PIL.Image.Image'>

# %%
print(dir(image))
# Out:
# ['_Image__transformer', '__array_interface__', '__class__', '__copy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_close_exclusive_fp_after_loading', '_copy', '_crop', '_dump', '_ensure_mutable', '_exif', '_expand', '_get_safe_box', '_getxmp', '_new', '_reload_exif', '_repr_image', '_repr_jpeg_', '_repr_png_', '_repr_pretty_', '_size', 'alpha_composite', 'apply_transparency', 'close', 'convert', 'copy', 'crop', 'draft', 'effect_spread', 'entropy', 'filter', 'format', 'format_description', 'frombytes', 'get_child_images', 'getbands', 'getbbox', 'getchannel', 'getcolors', 'getdata', 'getexif', 'getextrema', 'getim', 'getpalette', 'getpixel', 'ge
# ...

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080>

# %% [markdown]
# ### Demux Operation on Containers
# Demuxing the container yields packets from slected stream, which can be decoded to yield frame data

# %%
packet_generator = input_container.demux(video=0)

# %%
packet = next(packet_generator)

# %%
print(dir(packet))
# Out:
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__pyx_vtable__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', 'buffer_ptr', 'buffer_size', 'decode', 'decode_one', 'dts', 'duration', 'is_corrupt', 'is_keyframe', 'pos', 'pts', 'size', 'stream', 'stream_index', 'time_base', 'to_bytes', 'update']

# %%
float(packet.pts * packet.time_base)
# Out:
# 0.06666666666666667

# %%
print(packet.decode.__doc__)
# Out:
# Packet.decode()
#
#         Send the packet's data to the decoder and return a list of
#         :class:`.AudioFrame`, :class:`.VideoFrame` or :class:`.SubtitleSet`.

# %%
packet_generator = input_container.demux(video=0)
for i in range(0, 10):
    packet = next(packet_generator)
    for frame in packet.decode():
        print('frame:', frame)
        print('frame time:', frame.time)
# Out:
# frame: <av.VideoFrame #1, pts=200 yuv444p 1920x1080 at 0x7f4fd75b4c40>
# frame time: 0.13333333333333333
# frame: <av.VideoFrame #2, pts=300 yuv444p 1920x1080 at 0x7f4fd75b5d20>
# frame time: 0.2
# frame: <av.VideoFrame #3, pts=400 yuv444p 1920x1080 at 0x7f4fd75b5c60>
# frame time: 0.26666666666666666
# frame: <av.VideoFrame #4, pts=500 yuv444p 1920x1080 at 0x7f4fd75b4c40>
# frame time: 0.3333333333333333
# frame: <av.VideoFrame #5, pts=600 yuv444p 1920x1080 at 0x7f4fd75b5d20>
# frame time: 0.4
# frame: <av.VideoFrame #6, pts=700 yuv444p 1920x1080 at 0x7f4fd75b5c60>
# frame time: 0.4666666666666667
# frame: <av.VideoFrame #7, pts=800 yuv444p 1920x1080 at 0x7f4fd75b4c40>
# frame time: 0.5333333333333333
# frame: <av.VideoFrame #8, pts=900 yuv444p 1920x1080 at 0x7f4fd75b5d20>
# frame time: 0.6
# frame: <av.VideoFrame #9, pts=1000 yuv444p 1920x1080 at 0x7f4fd75b5c60>
# frame time: 0.6666666666666666
# frame: <av.VideoFrame #10, pts=1100 yuv444p 1920x1080 at 0x7f4fd75b4c40>
# ...

# %%
input_container.close()

# %%
output_container = av.open(path, 'w', format='mp4')

# %%
print(type(output_container))
# Out:
# <class 'av.container.output.OutputContainer'>

# %%
print(dir(output_container))
# Out:
# ['__class__', '__delattr__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__pyx_vtable__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '_get_flags', '_set_flags', 'add_stream', 'auto_bsf', 'bit_exact', 'close', 'container_options', 'custom_io', 'discard_corrupt', 'dumps_format', 'fast_seek', 'file', 'flags', 'flush_packets', 'format', 'gen_pts', 'ign_dts', 'ign_idx', 'io_open', 'metadata', 'metadata_encoding', 'metadata_errors', 'mux', 'mux_one', 'name', 'no_buffer', 'no_fill_in', 'no_parse', 'non_block', 'open_files', 'open_timeout', 'options', 'priv_opt', 'read_timeout', 'shortest', 'sort_dts', 'start_encoding', 'stream_options', 'streams', 'writeable']

# %% [markdown]
# ### Create video from images

# %%
container_1 = av.open(path, mode='w', format='mp4')

# %%
stream_1 = container_1.add_stream('h264', 25)

# %%
stream_1

# %%
print(dir(stream_1))
# Out:
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__pyx_vtable__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', 'average_rate', 'base_rate', 'codec_context', 'container', 'decode', 'duration', 'encode', 'frames', 'guessed_rate', 'id', 'index', 'language', 'metadata', 'profile', 'start_time', 'time_base', 'type']

# %%
images_path = Path('images')

# %%
for file in images_path.iterdir():
    try:
        image = PIL.Image.open(file)
    except IOError:
        pass
    else:
        frame = av.video.frame.VideoFrame.from_image(image)
        packets = stream_1.encode(frame)
        for packet in packets:
            container_1.mux(packet)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 for file in images_path.iterdir():
#       2     try:
#       3         image = PIL.Image.open(file)
#
# File /opt/conda/lib/python3.10/pathlib.py:1017, in Path.iterdir(self)
#    1013 def iterdir(self):
#    1014     """Iterate over the files in this directory.  Does not yield any
#    1015     result for the special paths '.' and '..'.
#    1016     """
# -> 1017     for name in self._accessor.listdir(self):
#    1018         if name in {'.', '..'}:
#    1019             # Yielding a path object for these makes little sense
#    1020             continue
#
# FileNotFoundError: [Errno 2] No such file or directory: 'images'

# %%
container_1.streams.video[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 container_1.streams.video[0]
#
# IndexError: tuple index out of range

# %%
for packet in stream_1.encode():
    container_1.mux(packet)

# %%
container_1.streams.video[0].frames
# Out:
# 82

# %%
container_1.close()

# %% [markdown]
# ### Extract frames from video to create another video

# %%
container_2 = av.open(path, mode='r')

# %%
container_3 = av.open('video_3.mp4', mode='w', format='mp4')
stream = container_3.add_stream('h264', 25)

# %%
frame_count = 0
packet_count = 0
flag = False
for packet in container_2.demux(video=0):
    packet_count += 1
    for frame in packet.decode():
        frame_count += 1
print("frame_count", frame_count)
print("packet_count", packet_count)
# Out:
# frame_count 725
# packet_count 726

# %%
container_2.streams.video[0].frames
# Out:
# 725

# %%
container_2 = av.open(path, mode='r')
container_3 = av.open('video_3.mp4', mode='w', format='mp4')
stream = container_3.add_stream('h264', 25)

for packet in container_2.demux(video=(0,)):
    for frame in packet.decode():
        for p in stream.encode(frame):
            container_3.mux(p)
container_2.close()
container_3.close()

# %%
import io
from abc import ABC, abstractmethod

import av
from PIL import Image
from math import floor
import requests
from pathlib import Path


class IMediaReader(ABC):
    def __init__(self, source_path, step, start, stop):
        self._source_path = sorted(source_path)
        self._step = step
        self._start = start
        self._stop = stop

    @abstractmethod
    def __iter__(self):
        pass

    def __len__(self):
        return len(self.frame_range)

    @property
    def frame_range(self):
        return range(self._start, self._stop, self._step)


class VideoReader(IMediaReader):
    def __init__(self, source_path, step=1, start=0, stop=None):
        super().__init__(
            source_path=source_path,
            step=step,
            start=start,
            stop=stop + 1 if stop is not None else stop,
        )

    def _has_frame(self, i):
        if i >= self._start:
            if (i - self._start) % self._step == 0:
                if self._stop is None or i < self._stop:
                    return True
        return False

    def _decode(self, container):
        frame_num = 0
        for packet in container.demux():
            if packet.stream.type == 'video':
                for image in packet.decode():
                    frame_num += 1
                    if self._has_frame(frame_num - 1):
                        yield (image, self._source_path[0], image.pts)

                        
    def __iter__(self):
        container = self._get_av_container()
        source_video_stream = container.streams.video[0]
        source_video_stream.thread_type = 'AUTO'
        return self._decode(container)

    def _get_av_container(self):
        if isinstance(self._source_path[0], io.BytesIO):
            self._source_path[0].seek(0) # required for re-reading
        return av.open(self._source_path[0])

    @property
    def length(self):
        container = self._get_av_container()
        source_video_stream = container.streams.video[0]

    @property
    def frame_rate(self):
        container = self._get_av_container()
        source_video_stream = container.streams.video[0]


class IChunkWriter(ABC):
    def __init__(self, quality):
        self._image_quality = quality

    @staticmethod
    def _compress_image(image_path, quality):
        image = image_path.to_image() if isinstance(image_path, av.VideoFrame) else Image.open(image_path)

        # Ensure image data fits into 8bit per pixel before RGB conversion as PIL clips values on conversion
        if image.mode == "I":
            # Image mode is 32bit integer pixels.
            # Autoscale pixels by factor 2**8 / im_data.max() to fit into 8bit
            im_data = np.array(image)
            im_data = im_data * (2**8 / im_data.max())
            image = Image.fromarray(im_data.astype(np.int32))
        converted_image = image.convert('RGB')
        image.close()
        buf = io.BytesIO()
        converted_image.save(buf, format='JPEG', quality=quality, optimize=True)
        buf.seek(0)
        width, height = converted_image.size
        converted_image.close()
        return width, height, buf

    @abstractmethod
    def save_as_chunk(self, images, chunk_path):
        pass


class Mpeg4ChunkWriter(IChunkWriter):
    def __init__(self, _):
        super().__init__(17)
        self._output_fps = 25

    @staticmethod
    def _create_av_container(path, w, h, rate, options, f='mp4'):
        # x264 requires width and height must be divisible by 2 for yuv420p
        if h % 2:
            h += 1
        if w % 2:
            w += 1

        container = av.open(path, 'w',format=f)
        video_stream = container.add_stream('libx264', rate=rate)
        video_stream.pix_fmt = "yuv420p"
        video_stream.width = w
        video_stream.height = h
        video_stream.options = options
        return container, video_stream

    def save_as_chunk(self, images, chunk_path):
        if not images:
            raise Exception('no images to save')

        input_w = images[0][0].width
        input_h = images[0][0].height

        output_container, output_v_stream = self._create_av_container(
            path=chunk_path,
            w=input_w,
            h=input_h,
            rate=self._output_fps,
            options={
                'profile': 'baseline',
                'qmin': str(self._image_quality),
                'qmax': str(self._image_quality),
                'rc_mode': 'buffer',
            },
        )
        self._encode_images(images, output_container, output_v_stream)
        output_container.close()
        return [(input_w, input_h)]

    @staticmethod
    def _encode_images(images, container, stream):
        for frame, _, _ in images:
            # let libav set the correct pts and time_base
            frame.pts = None
            frame.time_base = None

            for packet in stream.encode(frame):
                container.mux(packet)

        # Flush streams
        for packet in stream.encode():
            container.mux(packet)


class Mpeg4CompressedChunkWriter(Mpeg4ChunkWriter):
    def __init__(self, quality):
        # translate inversed range [1:100] to [0:51]
        self._image_quality = round(51 * (100 - quality) / 99)
        self._output_fps = 25

    def save_as_chunk(self, images, chunk_path):
        if not images:
            raise Exception('no images to save')

        input_w = images[0][0].width
        input_h = images[0][0].height

        # downscale_factor = 1
        # while input_w / downscale_factor > 1280:
        #     downscale_factor *= 2

        # output_h = input_h // downscale_factor
        # output_w = input_w // downscale_factor

        if input_w > 1280:
            output_w = 1280
            aspect_ratio = float(input_h)/input_w
            output_h = floor(aspect_ratio * output_w)
        else:
            output_w = input_w
            output_h = input_h

        output_container, output_v_stream = self._create_av_container(
            path=chunk_path,
            w=output_w,
            h=output_h,
            rate=self._output_fps,
            options={
                'profile': 'baseline',
                'qmin': str(self._image_quality),
                'qmax': str(self._image_quality),
                'rc_mode': 'buffer',
            },
        )
        self._encode_images(images, output_container, output_v_stream)
        output_container.close()
        return [(output_w, output_h)]

# %%
def save_as_chunk(frames, part_number):
    with open(f'test_{part_number}.mp4', mode='wb') as file:
        Mpeg4CompressedChunkWriter(100).save_as_chunk(frames, file)

with io.BytesIO() as file_obj:
    
path = str(Path("assets/parmeshwar.mp4").absolute())
file = open(path, mode='rb')
fp = io.BytesIO(initial_bytes=file.read())
video = VideoReader(source_path=[fp])
frames = []
frame_count = 0
part = 0
for frame in video:
    if frame_count == 200:
        part += 1
        save_as_chunk(frames, part)
        frames.clear()
        frame_count = 0
    frames.append(frame)
    frame_count += 1
# Out:
# specified frame type (3) at 0 is not compatible with keyframe interval
# specified frame type (3) at 0 is not compatible with keyframe interval
# specified frame type (3) at 0 is not compatible with keyframe interval
# specified frame type (3) at 0 is not compatible with keyframe interval
# specified frame type (3) at 0 is not compatible with keyframe interval
# specified frame type (3) at 0 is not compatible with keyframe interval
# specified frame type (3) at 0 is not compatible with keyframe interval
# specified frame type (3) at 0 is not compatible with keyframe interval
# specified frame type (3) at 0 is not compatible with keyframe interval
# specified frame type (3) at 0 is not compatible with keyframe interval
# specified frame type (3) at 0 is not compatible with keyframe interval
# specified frame type (3) at 0 is not compatible with keyframe interval
# specified frame type (3) at 0 is not compatible with keyframe interval
# ...

# %%
fp = io.BytesIO()

# %%
dir(fp)
# Out:
# ['__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '_checkClosed',
#  '_checkReadable',
#  '_checkSeekable',
#  '_checkWritable',
#  'close',
#  'closed',
#  'detach',
#  'fileno',
#  'flush',
#  'getbuffer',
#  'getvalue',
#  'isatty',
#  'read',
#  'read1',
#  'readable',
#  'readinto',
#  'readinto1',
#  'readline',
#  'readlines',
#  'seek',
#  'seekable',
#  'tell',
#  'truncate',
#  'writable',
#  'write',
#  'writelines']

# %% [markdown]
# # Random Library

# %%
import random

# %% [markdown]
# ## Most used methods
# - choice
# - choices
# - randbytes
# - random
# - randrange
# - sample
# - seed

# %% [markdown]
# # Unittest Library

# %%
from unittest.mock import MagicMock, patch
from unittest.mock import Mock

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
        
    def get_name(self):
        return self.name
        
    def get_age(self):
        return self.ageI would like to share a personal experience. I moved my heavy-lifting tasks to AWS Lambda and I must admit that the ROI has been pretty good. For instance, one of my tasks was to generate monthly statements for the customers and then mail them to the customers as well. The data for each statement was fed into a Jinja template which gave me an HTML of the statement. Using Weasyprint, I converted the HTML to a Pdf file. And then mailing those pdf statements was the last step. I researched through various options for creating pdf files directly, but they didn't looked feasible for me.I would like to share a personal experience. I moved my heavy-lifting tasks to AWS Lambda and I must admit that the ROI has been pretty good. For instance, one of my tasks was to generate monthly statements for the customers and then mail them to the customers as well. The data for each statement was fed into a Jinja template which gave me an HTML of the statement. Using Weasyprint, I converted the HTML to a Pdf file. And then mailing those pdf statements was the last step. I researched through various options for creating pdf files directly, but they didn't looked feasible for me.I would like to share a personal experience. I moved my heavy-lifting tasks to AWS Lambda and I must admit that the ROI has been pretty good. For instance, one of my tasks was to generate monthly statements for the customers and then mail them to the customers as well. The data for each statement was fed into a Jinja template which gave me an HTML of the statement. Using Weasyprint, I converted the HTML to a Pdf file. And then mailing those pdf statements was the last step. I researched through various options for creating pdf files directly, but they didn't looked feasible for me.I would like to share a personal experience. I moved my heavy-lifting tasks to AWS Lambda and I must admit that the ROI has been pretty good. For instance, one of my tasks was to generate monthly statements for the customers and then mail them to the customers as well. The data for each statement was fed into a Jinja template which gave me an HTML of the statement. Using Weasyprint, I converted the HTML to a Pdf file. And then mailing those pdf statements was the last step. I researched through various options for creating pdf files directly, but they didn't looked feasible for me.I would like to share a personal experience. I moved my heavy-lifting tasks to AWS Lambda and I must admit that the ROI has been pretty good. For instance, one of my tasks was to generate monthly statements for the customers and then mail them to the customers as well. The data for each statement was fed into a Jinja template which gave me an HTML of the statement. Using Weasyprint, I converted the HTML to a Pdf file. And then mailing those pdf statements was the last step. I researched through various options for creating pdf files directly, but they didn't looked feasible for me.I would like to share a personal experience. I moved my heavy-lifting tasks to AWS Lambda and I must admit that the ROI has been pretty good. For instance, one of my tasks was to generate monthly statements for the customers and then mail them to the customers as well. The data for each statement was fed into a Jinja template which gave me an HTML of the statement. Using Weasyprint, I converted the HTML to a Pdf file. And then mailing those pdf statements was the last step. I researched through various options for creating pdf files directly, but they didn't looked feasible for me.I would like to share a personal experience. I moved my heavy-lifting tasks to AWS Lambda and I must admit that the ROI has been pretty good. For instance, one of my tasks was to generate monthly statements for the customers and then mail them to the customers as well. The data for each statement was fed into a Jinja template which gave me an HTML of the statement. Using Weasyprint, I converted the HTML to a Pdf file. And then mailing those pdf statements was the last step. I researched through various options for creating pdf files directly, but they didn't looked feasible for me.I would like to share a personal experience. I moved my heavy-lifting tasks to AWS Lambda and I must admit that the ROI has been pretty good. For instance, one of my tasks was to generate monthly statements for the customers and then mail them to the customers as well. The data for each statement was fed into a Jinja template which gave me an HTML of the statement. Using Weasyprint, I converted the HTML to a Pdf file. And then mailing those pdf statements was the last step. I researched through various options for creating pdf files directly, but they didn't looked feasible for me.I would like to share a personal experience. I moved my heavy-lifting tasks to AWS Lambda and I must admit that the ROI has been pretty good. For instance, one of my tasks was to generate monthly statements for the customers and then mail them to the customers as well. The data for each statement was fed into a Jinja template which gave me an HTML of the statement. Using Weasyprint, I converted the HTML to a Pdf file. And then mailing those pdf statements was the last step. I researched through various options for creating pdf files directly, but they didn't looked feasible for me.

# %%
p1 = Person('karthik', 27)

# %%
p1.get_name()
# Out:
# 'karthik'

# %%
p1.get_name = MagicMock(return_value=28)

# %%
p1.get_name()
# Out:
# 28

# %% [markdown]
# ## Perform Side Effects

# %%
mock = Mock(side_effect=ValueError("foo"))

# %%
mock()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [17], line 1
# ----> 1 mock()
#
# File /usr/lib/python3.10/unittest/mock.py:1104, in CallableMixin.__call__(self, *args, **kwargs)
#    1102 self._mock_check_sig(*args, **kwargs)
#    1103 self._increment_mock_call(*args, **kwargs)
# -> 1104 return self._mock_call(*args, **kwargs)
#
# File /usr/lib/python3.10/unittest/mock.py:1108, in CallableMixin._mock_call(self, *args, **kwargs)
#    1107 def _mock_call(self, /, *args, **kwargs):
# -> 1108     return self._execute_mock_call(*args, **kwargs)
#
# File /usr/lib/python3.10/unittest/mock.py:1163, in CallableMixin._execute_mock_call(self, *args, **kwargs)
#    1161 if effect is not None:
#    1162     if _is_exception(effect):
# -> 1163         raise effect
#    1164     elif not _callable(effect):
#    1165         result = next(effect)
#
# ValueError: foo

# %% [markdown]
# # Threading

# %% [markdown]
# # OS Library

# %%
import os

# %%
os.environ.update({'foo': 'bar'})

# %%
dir(os.environ)
# Out:
# ['_MutableMapping__marker',
#  '__abstractmethods__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_data',
#  'clear',
#  'copy',
#  'decodekey',
#  'decodevalue',
#  'encodekey',
#  'encodevalue',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
os.environ['foo'] = 'goo'

# %%
os.environ['foo']
# Out:
# 'goo'
